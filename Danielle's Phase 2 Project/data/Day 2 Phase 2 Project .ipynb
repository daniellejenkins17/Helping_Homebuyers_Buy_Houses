# %%
#esc a is above, esc b is below, esc d d is delete cell

#look at data and see what I should do next 

#training data is called supervised machine learning- we are telling the computer what the answers are for the 
#training data. Computers are dumb and we need to feed them information. 
#If the training data isn't good, the testing data won't turn out good. 
#If the testing data is similar to the training data, 
#If you're overfitting, the line will be all over the place when it's really supposed to a simple line...
#you're forcefitting a squiggly line where there is supposed to be a straight line 
#Underfitting is when the line is too simple to explain the variance...data is all over the place and you try to 
#put a small, simple line there but it doesn't make sense 
#Show the model some of the data to train the model, and for the testing, it uses the rest of the data 
#train test split just splits it into train and test 

#1. Help homebuyers find a place that is the biggest bang for their buck 
#help real estate agents sell more houses 
#redlining- mortgages would not be given to non-white people in certain zip codes
#certain houses are undervalued in neighborhoods with more crime...? 
#neighborhoods where there is higher square footage for less price, but those won't always be the best 
#neighborhoods to live in 
#would need crime rate in neighborhood zip codes to see if the houses are worth risk to buy in those neighborhoods
#get crime rates for Seattle area from 2014-2015 (timeframe of our data)
#find data from 911 calls 

#2. Assisting the real estate agents with housing appraisal data: 
#Location of home.
#Size of land.
#Number of bedrooms and bathrooms.
#Square footage.
#Year built.
#Curb appeal.
#Major systems and home appliances.
#Condition of home and systems.

#price per bedroom or price per bedroom vs bathroom

#3. Which parts of city were redlined, and allocate that money to underpriveleged neighborhoods in the form of grants
#seattle crime rates 2014 map zip codes V.S. : 
#redlined areas in seattle zip codes 2014

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kc_house_data_cleaned.csv') #don't add data/ because I created the file 
#inside the data folder 
df
# Out:
#        Unnamed: 0          id     price  bedrooms  bathrooms  sqft_living  \
# 0               0  7129300520  221900.0         3       1.00         1180
# 1               1  6414100192  538000.0         3       2.25         2570
# 2               2  5631500400  180000.0         2       1.00          770
# 3               3  2487200875  604000.0         4       3.00         1960
# 4               4  1954400510  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592       21592   263000018  360000.0         3       2.50         1530
# 21593       21593  6600060120  400000.0         4       2.50         2310
# 21594       21594  1523300141  402101.0         2       0.75         1020
# 21595       21595   291310100  400000.0         3       2.50         1600
# 21596       21596  1523300157  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  yr_built  \
# ...

# %%
sns.pairplot(df[['price', 'bathrooms', 'grade', 'sqft_lot']]) #only looking at middle 2 on left side

# %%
sns.pairplot(df[['price', 'bedrooms', 'floors', 'sqft_living']])  #only looking at left bottom 3

# %%
sns.pairplot(df[['price', 'yr_built', 'floors']])  #only looking at bottom left 2

# %%
plt.figure(figsize= (10,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
features1 = ['bedrooms', 'bathrooms',  'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view','grade']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[features1], df['price'], test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print(regressor.score(X_train,y_train))
print(regressor.score(X_test, y_test))
# Out:
# 0.5924442287188192
# 0.5808734148385319

# %%
features2 = ['bedrooms', 'bathrooms', 'sqft_living', 'floors', 'grade', 'yr_built']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[features2], df['price'], test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print(regressor.score(X_train,y_train))
print(regressor.score(X_test, y_test))
# Out:
# 0.6085963340900665
# 0.6087373538979277

# %%
features3 = ['bedrooms', 'bathrooms', 'price', 'sqft_living', 'floors']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[features3], df['grade'], test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print(regressor.score(X_train,y_train))
print(regressor.score(X_test, y_test))
# Out:
# 0.6415140144907214
# 0.666045283695055

# %%
features4 = ['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[features4], df['grade'], test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print(regressor.score(X_train,y_train))
print(regressor.score(X_test, y_test))
# Out:
# 0.4409097815511359
# 0.3698713684656847
